# %%
n=int(input(" enter a number"))
if n%7==0:
    print("number is divisible by 7")
else:
        print("number is not divisible by 7")
# Out:
#  enter a number8
# number is not divisible by 7

# %%
x=input("enter a character")
if x in 'aeiouAEIOU':
    print("it is a vowel")
else:
    print(" not a vowel")
# Out:
# enter a characterA
# it is a vowel

# %%
n=int(input("enter the age"))
if n>=18:
    print("eligible to apply for driving licence")
else:
    print("not eligible")
# Out:
# enter the age26
# eligible to apply for driving licence

# %%
a=input("enter 1st string")
b=input("enter 2nd string")
if a==b:
    print("the strings are equal")
else:
    print("the strings are not equal")
# Out:
# enter 1st stringhai
# enter 2nd stringhello
# the strings are not equal

# %%
x=int(input("ener the amount"))
if x>5000:
    print("eligible for discount")
else:
    print("not eligible")
# Out:
# ener the amount10000
# eligible for discount

# %%
a=int(input("enter the number"))
if 10<= a <= 100:
    print("number lies between 10 and 100")
else:
    print("number does not lies between 10 and 100")
# Out:
# enter the number99
# number lies between 10 and 100

# %%
a=int(input("enter the attendence in percentage"))
if a>=75:
    print("eligible to attend exam")
else:
    print("not eligible to attend exam")
# Out:
# enter the attendence in percentage90
# eligible to attend exam

# %%
x=input("enter an alphabet=")
if "A"<= x<= "Z":
    print("uppercase")
else:
    print("lowercase")
# Out:
# enter an alphabet=g
# lowercase

# %%
x=int(input("enter a number="))
if 100<= x<=999:
    print("three-digit number")
else:
    print("not three-digit number")
# Out:
# enter a number=10
# not three-digit number

# %%
N=float(input("enter mobile data used in GB="))
if N<2:
    print("low usage")
elif 2<=N<=5:
    print("moderate usage")
else:
    print(" high usage")
# Out:
# enter mobile data used in GB=5.5
#  high usage
